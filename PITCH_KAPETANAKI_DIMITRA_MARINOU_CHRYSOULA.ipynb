# %% [markdown]
# # Data Project Pitch

# %% [markdown]
# ### Σύνοψη

# %% [markdown]
# <i>Περιγράψτε την ιδέα σας σε δυο-τρεις γραμμές εδώ</i>

# %% [markdown]
# Το θέμα μας αφορά τη κατανομή των ελληνικών κομμάτων στο Ευρωπαικό κοινοβούλιο από το 1981 μέχρι σήμερα. Θα δούμε τις τάσεις που επηρεάζουν την εκλογή συγκεκριμένων κομμάτων εις βάρος άλλων, τις χρονικές αλλαγές και τις σχέσεις που έχουν οι Έλληνες ευρωβουλευτές με άλλα μέλη του Ευρωπαικού Κοινοβουλίου.

# %% [markdown]
# ### Έμπνευση

# %% [markdown]
# - <i>Βάλτε εδώ ένα link προς ένα θέμα που έχετε δει να είναι ήδη δημοσιευμένο και λειτουργεί ως έμπνευση για εσάς για το συγκεκριμένο πρότζεκτ που θέλετε να κάνετε.</i>
# - <i>Βάλτε, επίσης, μια εικόνα ενός γραφήματος που έχετε δει, σας αρέσει και πιστεύετε ότι κάπως έτσι μπορείτε να παρουσιάσετε και εσείς την ανάλυσή σας. Το γράφημα αυτό μπορεί, φυσικά, να αφορά και διαφορετικό θέμα από το δικό σας.</i>

# %% [markdown]
# Η εμπνευση μας προήλθε από την ιστοσελίδα https://vouliwatch.gr/  και την απουσία μίας αντίστοιχής προσπάθειας για το ευρωπαικό κοινοβούλιο. Παρόλα αυτά, θέλουμε να θέσουμε δικά μας ερευνητικά ερωτήματα τα οποία δεν έχουμε δει να εμφανίζονται σε άλλες έρευνες. Ως συμπληρωματική βιβλιογραφία θα χρησιμοποιήσουμε πηγές όπως οι παρακάτω.
#
# https://journals.sagepub.com/doi/full/10.1177/0020731416660963?casa_token=m5gM9IkYAIIAAAAA%3AuSyGHL_HiBcXBNqD2L83S0d_7ERicMEVL5h3Gy7ZJT3x9PsiiSG9h-vawu49Eaqhr-jVAE_JpL33rg
#
# https://www.sciencedirect.com/science/article/pii/S026137941000106X

# %% [markdown]
# ![318975587_668158641699932_9024831236165987718_n.png](attachment:318975587_668158641699932_9024831236165987718_n.png)

# %% [markdown]
# ### Περαιτέρω πληροφορίες για το θέμα σας

# %% [markdown]
# - <b>Τίτλος εργασίας</b>:
#
#   <i>  Η Ελλάδα στο Ευρωπαϊκό Κοινοβούλιο από το 1981 έως το 2024: η αντιστοιχία των ελληνικών θέσεων και οι πιθανοί παράγοντες επιρροής της εκάστοτοτε κατανομής </i>
# <br><br>
#
# - <b>Δεδομένα</b>:
#
#    Θα χρειαστεί να κάνουμε scraping στις παρακάτω ιστοσελίδες https://www.europarl.europa.eu/about-parliament/el/in-the-past/previous-elections.
# https://www.ertnews.gr/frontpage/oi-ellinikes-eyroekloges-apo-to-1981-eos-to-2014/?fbclid=IwAR1tfx3b1204znJtuOLOCOv_GEt9iSjT5PgsgGuUc3GBzQu1TPgDNKEOYU4
# https://www.europarl.europa.eu/election-results-2019/el/ekloges-apotelesmata/2009-2014/syntaktiki-sinelefsi/
# https://www.europarl.europa.eu/election-results-2019/el/ergaleia/lipsi-deltion-stoiheion/?fbclid=IwAR0SGcgf-zFbjj_sQp6t_9il0iAWjUITN3qdZn0bxUVXiimhCeD13K8vtjk
# <br><br>
# - <b>Πιθανά προβλήματα/ανασφάλειες/απορίες</b>:
#
#   Η ιστοσελίδα https://www.europarl.europa.eu/about-parliament/el/in-the-past/previous-elections, παρόλου που δίνει την επιλογή, φαίνεται να μην επιτρέπει την αναδρομή σε προηγούμενες εκλογικές περιόδους. Πιστεύουμε πως τα δεδομένα μπορούν να βρεθούν μέσω scraping αλλά δεν έχουμε την απαραίτητη τεχνογνωσία.
#
#   Επίσης, σε αυτή την ιστοσελίδα https://www.europarl.europa.eu/election-results-2019/el/ergaleia/lipsi-deltion-stoiheion/?fbclid=IwAR0SGcgf-zFbjj_sQp6t_9il0iAWjUITN3qdZn0bxUVXiimhCeD13K8vtjk, αν και περιέχει τα περισσότερα δεδομένα, είναι σχεδόν όλα σε μορφή φωτογραφίας.
#
#   Ένα ακόμα πρόβλημα που προέκυψε στην περαιτέρω έρευνα που κάναμε για να συλλέξουμε τα δεδομένα μας, ήταν το γεγονός ότι, αρχεία που αφορούν το ιστορικό των εκλογών από προηγούμενες χρονιές όσον αφορά τους Ευρωβουλευτές ξεχωριστά είναι πολύ δύσκολο να βρεθούν, αν υπάρχουν. Προσπαθούμε να σκεφτούμε έναν τρόπο με τον οποίο θα μπορέσουμε να αποκτήσουμε πρόσβαση σε αυτά τα δεδομένα, είτε με περισσότερο ψάξιμο, είτε με επικοινωνία απευθείας με το εκάστοτε κόμμα. Το μόνο που έχουμε βρει μέχρι στιγμής είναι αυτό το "dataset", το οποίο δεν έχουμε κατασταλλάξει ακόμα στο πώς θα το διαχειριστούμε ακριβώς.
# http://ekloges-info.ypes.gr/ΕΚΛΟΓΕΣ%20ΓΙΑ%20ΤΟ%20ΕΥΡΩΠΑΙΚΟ%20ΚΟΙΝΟΒΟΥΛΙΟ/ΑΠΟΤΕΛΕΣΜΑΤΑ%20ΕΥΡΩΚΛΟΓΩΝ/

# %% [markdown]
# ## Ερευνητικά ερωτήματα

# %% [markdown]
# <i> Σημειώστε εδώ σε λίστα τα ερευνητικά ερωτήματα που θέλετε να απαντήσετε με αυτό το πρότζεκτ.</i>

# %% [markdown]
# 1.Ποια ελληνικά κόμματα φαίνεται να εκλέγονται περισσότερο στο ευρωκοινοβούλιο;
# 3.Σε ποιές ευρωπαϊκές ομάδες φαίνεται να κατατάσσονται συνήθως οι Έλληνες ευρωβουλευτές;

# %% [markdown]
# ## Προέρευνα/δουλειά που έχετε ήδη κάνει στο πλαίσιο του σχεδιασμού του πρότζεκτ

# %% [markdown]
# - <i>Εξηγήστε συνοπτικά τη δουλειά που έχετε κάνει μέχρι τώρα, στο πλαίσιο της προετοιμασίας. Έχετε βρει δεδομένα; Τα έχετε κοιτάξει; Τα έχετε καθαρίσει; </i>
#
# Μέχρι στιγμής, έχουμε βρει ένα συγκεκριμένο όγκο δεδομένων σε μορφή cvs, τα οποία ανοίξαμε, διαβάσαμε και "καθαρίσαμε" σε δύο ξεχωριστά jupyter notebooks. Πρόκειται για τις πολιτικές ομάδες και τα εθνικά κόμματα που έχουν εκλεγεί στο Ευρωκοινοβούλιο κατά την περίοδο που μας ενδιαφέρει. Σκοπός μας στη συνέχεια είνα να βρούμε δεδομένα για τους Ευρωβουλευτές ξεχωριστά, ώστε να μπορέσουμε να ξεκινήσουμε τις συγκρίσεις που μας απασχολούν όσον αφορά το πόσοι Έλληνες Ευρωβουλευτές έχουν εκλεγεί σε κάθε κόμμα στο Ευρωπαϊκό Κοινοβούλιο.
#
# -> Τα jupyter αυτά υπάρχουν σε ξεχωριστό φάκελο που έχει σταλθεί μαζί με το Pitch μας.
# <br><br>
# - <i>Βάλτε εδώ μια εικόνα (π.χ. ένα γράφημα ή μια πρώιμη ανάλυση) που να δείχνει κάποιο πρώτο εύρημά σας, το οποίο σας κάνει να θέλετε να ερευνήσετε περαιτέρω/καλύτερα το θέμα</i>

# %% [markdown]
# ![epp.png](attachment:epp.png)

# %% [markdown]
# Ένα έυρημα το οποίο μας ενέπνευσε να ψάξουμε περισσότερο τον συσχετισμό εδρών των κομμάτων μέσα στην πολιτική ομάδα ήταν η πολιτική ομάδα των Χριστιανοδημοκρατών. Μας ώθησε στο να δούμε πώς διαμορφώνονται τα ποσοστά αυτά για τις υπόλοιπες πολιτικές ομάδες του Ευρωκοινοβουλίου και αν τα κόμματά μας καταλαμβάνουν μεγαλύτερο, μικρότερο ή ίδιο αριθμό εδρών στις υπόλοιπες ομάδες.

# %% [markdown]
# ## Απαντήστε "YES" ή "NO" στα παρακάτω ερωτήματα
# <i>(Στο στάδιο της πρότασης θέματος που βρίσκεστε, το αναμενόμενο είναι YES. Όσα περισσότερα NO, τόσο λιγότερο έχετε προετοιμαστεί και, άρα, χρειάζεται να σχεδιάσετε καλύτερα το πρότζεκτ σας.)</i>

# %%
input("Έχετε ψάξει για πηγές δεδομένων για το θέμα που θέλετε να κάνετε;")

# %%
input("Έχετε βρει δεδομένα/πηγές δεδομένων για το θέμα που θέλετε να κάνετε;")

# %%
input("Έχετε περάσει χρόνο εξερευνώντας τα δεδομένα σας; Έχετε καταλάβει τι έχετε, σε ποια μορφή είναι και ενδεχομένως τι σας λείπει;")

# %%
input("Έχετε διατυπώσει τα ερευνητικά ερωτήματά σας;")

# %%
input("Έχετε σκεφτεί πώς θα αναλύσετε τα δεδομένα σας, για να απαντήσετε τα ερευνητικά ερωτήματά σας;")

# %%
input("Έχετε αρχίσει να σκέφτεστε πώς θα μπορούσατε να οπτικοποιήσετε τις αναλύσεις σας για το τελικό σας story;")

# %%
input("Έχετε καταθέσει το pitch σας (το προτεινόμενο θέμα σας) σε ένα notebook με filename PITCH_ΟΝΟΜΑΤΕΠΩΝΥΜΟ1_ΟΝΟΜΑΤΕΠΩΝΥΜΟ2;")
