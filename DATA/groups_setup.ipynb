# %%
#αποτελέσματα εκλογών - πολιτικές ομάδες (groups)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
g79 = pd.read_csv('groups_79.csv', sep=';')
g79 = g79[g79.LANGUAGE_ID.str.contains('EL')]
g79 = g79[['LANGUAGE_ID','ID','ACRONYM','LABEL']].copy()
g79
# Out:
#     LANGUAGE_ID      ID ACRONYM  \
# 6            EL  GP0001       S
# 30           EL  GP0002     PPE
# 54           EL  GP0003      ED
# 78           EL  GP0004     COM
# 102          EL  GP0005       L
# 126          EL  GP0006     DEP
# 150          EL  GP0007     CDI
# 174          EL     NaN      NI
#
#                                                  LABEL
# 6                                   Σοσιαλιστική Ομάδα
# 30   Ομάδα του Ευρωπαϊκού Λαϊκού Κόμματος (Χριστιαν...
# 54                      Ομάδα των Ευρωπαίων Δημοκρατών
# 78                Κομμουνιστική ομάδα και Προσκείμενοι
# 102                  Φιλελεύθερη και Δημοκρατική Ομάδα
# 126             Ομάδα τωv Ευρωπαίωv Δημoκρατώv Πρoόδου
# 150  Ομάδα Τεχνικού Συντονισμού και Προασπίσεως Ανε...
# 174                                   Μη Εγγεγραμμένοι

# %%
g84 = pd.read_csv('groups_84.csv', sep=';')
g84 = g84[g84.LANGUAGE_ID.str.contains('EL')]
g84 = g84[['LANGUAGE_ID','ID','ACRONYM','LABEL']].copy()
g84
# Out:
#     LANGUAGE_ID      ID ACRONYM  \
# 6            EL  GP0201       S
# 30           EL  GP0202     PPE
# 54           EL  GP0203      ED
# 78           EL  GP0204     COM
# 102          EL  GP0205       L
# 126          EL  GP0206     RDE
# 150          EL  GP0207     ARC
# 174          EL  GP0208      DR
# 198          EL     NaN      NI
#
#                                                  LABEL
# 6                                   Σοσιαλιστική Ομάδα
# 30   Ομάδα του Ευρωπαϊκού Λαϊκού Κόμματος (Χριστιαν...
# 54                      Ομάδα των Ευρωπαίων Δημοκρατών
# 78                Κομμουνιστική ομάδα και Προσκείμενοι
# 102                  Φιλελεύθερη και Δημοκρατική Ομάδα
# 126         Ομάδα Συνασπισμού των Ευρωπαίων Δημοκρατών
# 150  Ομάδα 'Ουράνιο Τόξο': Ομοσπονδία του Ευρωπαϊκο...
# 174           Ομάδα των Κομμάτων της Ευρωπαϊκής Δεξιάς
# 198                                   Μη Εγγεγραμμένοι

# %%
g89 = pd.read_csv('groups_89.csv', sep=';')
g89 = g89[g89.LANGUAGE_ID.str.contains('EL')]
g89 = g89[['LANGUAGE_ID','ID','ACRONYM','LABEL']].copy()
g89
# Out:
#     LANGUAGE_ID      ID ACRONYM  \
# 6            EL  GP0401       S
# 30           EL  GP0402     PPE
# 54           EL  GP0403     LDR
# 78           EL  GP0404      ED
# 102          EL  GP0405       V
# 126          EL  GP0406     GUE
# 150          EL  GP0407     RDE
# 174          EL  GP0408      DR
# 198          EL  GP0409      CG
# 222          EL  GP0410     ARC
# 246          EL     NaN      NI
#
#                                                  LABEL
# 6                                   Σοσιαλιστική Ομάδα
# 30   Ομάδα του Ευρωπαϊκού Λαϊκού Κόμματος (Χριστιαν...
# 54   Φιλελεύθερη, Δημοκρατική και Μεταρρυθμιστική Ο...
# 78                      Ομάδα των Ευρωπαίων Δημοκρατών
# 102       Ομάδα των Πρασίνων στο Ευρωπαϊκό Κοινοβούλιο
# 126           Ομάδα για την Ευρωπαϊκή Ενωτική Αριστερά
# 150         Ομάδα Συνασπισμού των Ευρωπαίων Δημοκρατών
# 174  Ομάδα Τεχνικού Συντονισμού των Κομμάτων της Ευ...
# 198                          Συνασπισμός της Αριστεράς
# ...

# %%
g94 = pd.read_csv('groups_94.csv', sep=';')
g94 = g94[g94.LANGUAGE_ID.str.contains('EL')]
g94 = g94[['LANGUAGE_ID','ID','ACRONYM','LABEL']].copy()
g94
# Out:
#     LANGUAGE_ID      ID ACRONYM  \
# 6            EL  GP0601     PSE
# 30           EL  GP0602     PPE
# 54           EL  GP0603    ELDR
# 78           EL  GP0604     GUE
# 102          EL  GP0605      FE
# 126          EL  GP0606     RDE
# 150          EL  GP0607       V
# 174          EL  GP0608     ARE
# 198          EL  GP0609     EDN
# 222          EL     NaN      NI
#
#                                                  LABEL
# 6          Ομάδα του Ευρωπαϊκού Σοσιαλιστικού Κόμματος
# 30   Ομάδα του Ευρωπαϊκού Λαϊκού Κόμματος (Χριστιαν...
# 54   Ομάδα του Ευρωπαϊκού Κόμματος των Φιλελευθέρων...
# 78   Συνομοσπονδιακή Ομάδα της Ευρωπαϊκής Ενωτικής ...
# 102                                 Ομάδα Forza Europa
# 126         Ομάδα Συνασπισμού των Ευρωπαίων Δημοκρατών
# 150       Ομάδα των Πρασίνων στο Ευρωπαϊκό Κοινοβούλιο
# 174       Ομάδα της Ευρωπαϊκής Ριζοσπαστικής Συμμαχίας
# 198         Ομάδα Ευρώπη των Εθνών (Ομάδα συντονισμού)
# ...

# %%
g99 = pd.read_csv('groups_99.csv', sep=';')
g99 = g99[g99.LANGUAGE_ID.str.contains('EL')]
g99 = g99[['LANGUAGE_ID','ID','ACRONYM','LABEL']].copy()
g99
# Out:
#     LANGUAGE_ID      ID    ACRONYM  \
# 6            EL  GP0801     ΕΛΚ-ΕΔ
# 30           EL  GP0802        PSE
# 54           EL  GP0803       ELDR
# 78           EL  GP0804  Verts/ALE
# 102          EL  GP0805    GUE/NGL
# 126          EL  GP0806        UEN
# 150          EL  GP0807        TDI
# 174          EL  GP0808        EDD
# 198          EL     NaN         NI
#
#                                                  LABEL
# 6    Ομάδα τoυ Ευρωπαϊκoύ Λαϊκoύ Κόμματoς (Χριστιαv...
# 30         Ομάδα του Ευρωπαϊκού Σοσιαλιστικού Κόμματος
# 54   Ομάδα του Ευρωπαϊκού Κόμματος των Φιλελευθέρων...
# 78    Ομάδα τωv Πρασίvωv / Ευρωπαϊκή Ελεύθερη Συμμαχία
# 102  Συνομοσπονδιακή Ομάδα της Ευρωπαϊκής Ενωτικής ...
# 126              Ομάδα ΄Εvωση για τηv Ευρώπη τωv Εθvώv
# 150  Ομάδα Τεχvικoύ Συvτovισμoύ τωv Αvεξαρτήτωv Βoυ...
# 174  Ομάδα για την Ευρώπη της Δημoκρατίας και της Δ...
# 198                                   Μη Εγγεγραμμένοι

# %%
g04 = pd.read_csv('groups_04.csv', sep=';')
g04 = g04[g04.LANGUAGE_ID.str.contains('EL')]
g04 = g04[['LANGUAGE_ID','ID','ACRONYM','LABEL']].copy()
g04
# Out:
#     LANGUAGE_ID      ID    ACRONYM  \
# 6            EL  GP1001     ΕΛΚ-ΕΔ
# 30           EL  GP1002        PSE
# 54           EL  GP1003       ALDE
# 78           EL  GP1004  Verts/ALE
# 102          EL  GP1005    GUE/NGL
# 126          EL  GP1006        UEN
# 150          EL  GP1007    IND/DEM
# 174          EL     NaN         NI
#
#                                                  LABEL
# 6    Ομάδα τoυ Ευρωπαϊκoύ Λαϊκoύ Κόμματoς (Χριστιαv...
# 30        Σοσιαλιστική Ομάδα στο Ευρωπαϊκό Κοινοβούλιο
# 54   Ομάδα της Συμμαχίας Φιλελευθέρων και Δημοκρατώ...
# 78    Ομάδα τωv Πρασίvωv / Ευρωπαϊκή Ελεύθερη Συμμαχία
# 102  Συνομοσπονδιακή Ομάδα της Ευρωπαϊκής Ενωτικής ...
# 126               Ομάδα Έvωση για τηv Ευρώπη τωv Εθvώv
# 150                       Ομάδα Ανεξαρτησία/Δημοκρατία
# 174                                   Μη Εγγεγραμμένοι

# %%
g09 = pd.read_csv('groups_09.csv', sep=';')
g09 = g09[g09.LANGUAGE_ID.str.contains('EL')]
g09 = g09[['LANGUAGE_ID','ID','ACRONYM','LABEL']].copy()
g09
# Out:
#     LANGUAGE_ID      ID    ACRONYM  \
# 6            EL  GP1201        ΕΛΚ
# 30           EL  GP1202        S&D
# 54           EL  GP1203       ALDE
# 78           EL  GP1204  Verts/ALE
# 102          EL  GP1205        ΕΣΜ
# 126          EL  GP1206    GUE/NGL
# 150          EL  GP1207        EFD
# 174          EL     NaN         NI
#
#                                                  LABEL
# 6    Κoιvoβoυλευτική Ομάδα τoυ Ευρωπαϊκoύ Λαϊκoύ Κό...
# 30   Ομάδα της Προοδευτικής Συμμαχίας των Σοσιαλιστ...
# 54   Ομάδα της Συμμαχίας Φιλελευθέρων και Δημοκρατώ...
# 78    Ομάδα τωv Πρασίvωv / Ευρωπαϊκή Ελεύθερη Συμμαχία
# 102  Ομάδα των Ευρωπαίων Συντηρητικών και Μεταρρυθμ...
# 126  Συνομοσπονδιακή Ομάδα της Ευρωπαϊκής Ενωτικής ...
# 150                  Ευρώπη ελευθερίας και δημοκρατίας
# 174                                   Μη Εγγεγραμμένοι

# %%
g14 = pd.read_csv('groups_14.csv', sep=';')
g14 = g14[g14.LANGUAGE_ID.str.contains('EL')]
g14 = g14[['LANGUAGE_ID','ID','ACRONYM','LABEL']].copy()
g14
# Out:
#     LANGUAGE_ID      ID    ACRONYM  \
# 6            EL  GP1401        ΕΛΚ
# 30           EL  GP1402        S&D
# 54           EL  GP1403        ΕΣΜ
# 78           EL  GP1404       ALDE
# 102          EL  GP1405    GUE/NGL
# 126          EL  GP1406  Verts/ALE
# 150          EL  GP1407       EFDD
# 174          EL     NaN         NI
#
#                                                  LABEL
# 6    Κoιvoβoυλευτική Ομάδα τoυ Ευρωπαϊκoύ Λαϊκoύ Κό...
# 30   Ομάδα της Προοδευτικής Συμμαχίας των Σοσιαλιστ...
# 54   Ομάδα των Ευρωπαίων Συντηρητικών και Μεταρρυθμ...
# 78   Ομάδα της Συμμαχίας Φιλελευθέρων και Δημοκρατώ...
# 102  Συνομοσπονδιακή Ομάδα της Ευρωπαϊκής Ενωτικής ...
# 126   Ομάδα τωv Πρασίvωv / Ευρωπαϊκή Ελεύθερη Συμμαχία
# 150     Ομάδα Ευρώπη Ελευθερίας και Άμεσης Δημοκρατίας
# 174                                   Μη Εγγεγραμμένοι
